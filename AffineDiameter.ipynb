# %% [markdown]
# Note: running on PyPy is much faster.

# %%
import math
from itertools import combinations
from collections import defaultdict
from random import sample
from tqdm import tqdm

def minimum_distance(lst, p=127):
    res = float("+inf")
    for c in range(1, p):
        xcs = [x*c % p for x in lst]
        for base in xcs:
            sub = xcs[:]
            for i in range(len(sub)):
                sub[i] -= base
                if sub[i] < 0:
                    sub[i] += p
            res = min(res, max(sub))
    return res

def minimize(lst, p=127):
    v = minimum_distance(lst, p=p)
    for c in range(1, p):
        for base in [x*c % p for x in lst]:
            sub = sorted((x*c - base) % p for x in lst)
            if sub[-1] == v:
                return sub
    raise

# %% [markdown]
# # Exhaustive for $3 \le z \le 7$

# %%
def exhaustive(z, p=127):
    print("|E| = z =", z)
    
    lst = defaultdict(list)
    total = 0
    seen = 0
    domain = list(range(2, p))
    _total = math.factorial(p) // math.factorial(z-2) // math.factorial(p-(z-2))
    for inds in tqdm(combinations(domain, z-2), total=_total):
        seen += 1
        diam = minimum_distance((0,1) + inds)
        total += diam
        if len(lst[diam]) < 50:
            lst[diam].append(inds)

    global datas
    datas[z] = (lst, seen, total)
    
    print("avg", total / seen)
    for k, v in sorted(dict(lst).items()):
        print(k, len(v), v[:5])
    print("max affine diameter", k, "example", minimize((0, 1) + v[0]))
    print()

# %%
datas = {}

# %% [markdown]
# ## z=3

# %%
exhaustive(z=3)
# Out:
# |E| = z = 3
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 125/127 [00:00<00:00, 4884.32it/s]
# avg 8.032
# 2 3 [(2,), (64,), (126,)]
# 3 6 [(3,), (43,), (63,), (65,), (85,)]
# 4 6 [(4,), (32,), (42,), (86,), (96,)]
# 5 12 [(5,), (26,), (33,), (44,), (51,)]
# 6 6 [(6,), (22,), (52,), (76,), (106,)]
# 7 18 [(7,), (19,), (21,), (25,), (31,)]
# 8 12 [(8,), (16,), (18,), (27,), (45,)]
# 9 18 [(9,), (15,), (17,), (29,), (34,)]
# 10 12 [(10,), (13,), (14,), (39,), (40,)]
# 11 30 [(11,), (12,), (23,), (24,), (28,)]
# 13 2 [(20,), (108,)]
# max affine diameter 13 example [0, 7, 13]

# %% [markdown]
# ## z=4

# %%
exhaustive(z=4)
# Out:
# |E| = z = 4
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉      | 7750/8001 [00:00<00:00, 26852.43it/s]
# avg 17.809032258064516
# 3 6 [(2, 3), (2, 126), (43, 85), (63, 64), (64, 65)]
# 4 18 [(2, 4), (2, 64), (2, 65), (2, 125), (3, 4)]
# 5 36 [(2, 5), (2, 63), (2, 66), (2, 124), (3, 5)]
# 6 50 [(2, 6), (2, 43), (2, 44), (2, 85), (2, 86)]
# 7 50 [(2, 7), (2, 42), (2, 62), (2, 67), (2, 87)]
# 8 50 [(2, 8), (2, 32), (2, 33), (2, 45), (2, 84)]
# 9 50 [(2, 9), (2, 34), (2, 61), (2, 68), (2, 95)]
# 10 50 [(2, 10), (2, 26), (2, 27), (2, 41), (2, 51)]
# 11 50 [(2, 11), (2, 31), (2, 46), (2, 53), (2, 60)]
# 12 50 [(2, 12), (2, 22), (2, 23), (2, 25), (2, 104)]
# 13 50 [(2, 13), (2, 21), (2, 28), (2, 35), (2, 40)]
# 14 50 [(2, 14), (2, 19), (2, 20), (2, 37), (2, 38)]
# 15 50 [(2, 15), (2, 18), (2, 30), (2, 58), (2, 71)]
# ...

# %% [markdown]
# ## z=5

# %%
exhaustive(z=5)
# Out:
# |E| = z = 5
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████         | 317750/333375 [00:14<00:00, 21470.94it/s]
# avg 27.466687647521635
# 4 10 [(2, 3, 4), (2, 3, 126), (2, 64, 65), (2, 125, 126), (32, 64, 96)]
# 5 40 [(2, 3, 5), (2, 3, 125), (2, 4, 5), (2, 4, 126), (2, 63, 64)]
# 6 50 [(2, 3, 6), (2, 3, 64), (2, 3, 65), (2, 3, 66), (2, 3, 124)]
# 7 50 [(2, 3, 7), (2, 3, 63), (2, 3, 67), (2, 3, 123), (2, 4, 7)]
# 8 50 [(2, 3, 8), (2, 3, 122), (2, 4, 8), (2, 4, 64), (2, 4, 65)]
# 9 50 [(2, 3, 9), (2, 3, 43), (2, 3, 44), (2, 3, 45), (2, 3, 62)]
# 10 50 [(2, 3, 10), (2, 3, 42), (2, 3, 88), (2, 3, 120), (2, 4, 10)]
# 11 50 [(2, 3, 11), (2, 3, 46), (2, 3, 61), (2, 3, 69), (2, 3, 84)]
# 12 50 [(2, 3, 12), (2, 3, 32), (2, 3, 33), (2, 3, 34), (2, 3, 96)]
# 13 50 [(2, 3, 13), (2, 3, 35), (2, 3, 41), (2, 3, 60), (2, 3, 70)]
# ...

# %% [markdown]
# ## z=6

# %%
exhaustive(z=6)
# Out:
# |E| = z = 6
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎           | 9691375/10334625 [11:12<00:44, 14410.34it/s]
# avg 36.09349602094646
# 5 15 [(2, 3, 4, 5), (2, 3, 4, 126), (2, 3, 125, 126), (2, 63, 64, 65), (2, 64, 65, 66)]
# 6 50 [(2, 3, 4, 6), (2, 3, 4, 125), (2, 3, 5, 6), (2, 3, 5, 126), (2, 3, 64, 65)]
# 7 50 [(2, 3, 4, 7), (2, 3, 4, 124), (2, 3, 5, 7), (2, 3, 5, 125), (2, 3, 6, 7)]
# 8 50 [(2, 3, 4, 8), (2, 3, 4, 64), (2, 3, 4, 65), (2, 3, 4, 66), (2, 3, 4, 67)]
# 9 50 [(2, 3, 4, 9), (2, 3, 4, 63), (2, 3, 4, 68), (2, 3, 4, 122), (2, 3, 5, 9)]
# 10 50 [(2, 3, 4, 10), (2, 3, 4, 121), (2, 3, 5, 10), (2, 3, 5, 64), (2, 3, 5, 65)]
# 11 50 [(2, 3, 4, 11), (2, 3, 4, 62), (2, 3, 4, 69), (2, 3, 4, 120), (2, 3, 5, 11)]
# 12 50 [(2, 3, 4, 12), (2, 3, 4, 43), (2, 3, 4, 44), (2, 3, 4, 45), (2, 3, 4, 46)]
# ...

# %% [markdown]
# ## z=7

# %%
exhaustive(z=7)
# Out:
# |E| = z = 7
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉              | 234531275/254231775 [5:55:18<29:50, 11001.13it/s]
# avg 43.56442747347875
# 6 21 [(2, 3, 4, 5, 6), (2, 3, 4, 5, 126), (2, 3, 4, 125, 126), (2, 3, 64, 65, 66), (2, 3, 124, 125, 126)]
# 7 50 [(2, 3, 4, 5, 7), (2, 3, 4, 5, 125), (2, 3, 4, 6, 7), (2, 3, 4, 6, 126), (2, 3, 4, 124, 125)]
# 8 50 [(2, 3, 4, 5, 8), (2, 3, 4, 5, 124), (2, 3, 4, 6, 8), (2, 3, 4, 6, 125), (2, 3, 4, 7, 8)]
# 9 50 [(2, 3, 4, 5, 9), (2, 3, 4, 5, 123), (2, 3, 4, 6, 9), (2, 3, 4, 6, 124), (2, 3, 4, 7, 9)]
# 10 50 [(2, 3, 4, 5, 10), (2, 3, 4, 5, 64), (2, 3, 4, 5, 65), (2, 3, 4, 5, 66), (2, 3, 4, 5, 67)]
# 11 50 [(2, 3, 4, 5, 11), (2, 3, 4, 5, 63), (2, 3, 4, 5, 69), (2, 3, 4, 5, 121), (2, 3, 4, 6, 11)]
# 12 50 [(2, 3, 4, 5, 12), (2, 3, 4, 5, 120), (2, 3, 4, 6, 12), (2, 3, 4, 6, 64), (2, 3, 4, 6, 65)]
# ...

# %% [markdown]
# # Random sampling

# %%
def random_sampling(z, p=127, HOURS=1):
    global datas
    if z in datas:
        lst, seen, total = datas[z]
    else:
        lst = defaultdict(list)
        seen = 0
        total = 0
    
    domain = list(range(2, p))
    
    for _ in tqdm(range(int(2*10**7*HOURS))):
        suff = sample(domain, z-2)
        diam = minimum_distance([0,1] + suff)
        total += diam
        seen += 1
        if len(lst[diam]) < 50:
            lst[diam].append(suff)
    
    datas[z] = (lst, seen, total)
    
    print("...")
    for k, v in sorted(dict(lst).items())[-10:]:
        print(k, len(v), v[:5])
    print("avg", total / seen)
    print("max affine diameter", k, "example", minimize((0, 1) + tuple(v[0])))
    print()

# %%
HOURS = 1.0

# %% [markdown]
# ## z=8

# %%
random_sampling(8, HOURS=HOURS)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [00:02<00:00, 8126.14it/s]
# ...
# 63 50 [[76, 120, 38, 60, 43, 108], [38, 19, 97, 45, 90, 100], [80, 67, 10, 30, 55, 63], [47, 83, 32, 12, 42, 106], [125, 43, 21, 89, 15, 27]]
# 64 50 [[107, 86, 91, 2, 76, 45], [9, 118, 3, 42, 75, 99], [100, 82, 87, 92, 40, 21], [74, 41, 82, 92, 27, 102], [116, 48, 78, 24, 119, 117]]
# 65 50 [[52, 53, 103, 23, 107, 14], [43, 46, 58, 27, 122, 86], [108, 24, 2, 65, 32, 7], [126, 50, 71, 40, 4, 99], [72, 99, 15, 62, 18, 93]]
# 66 50 [[18, 81, 55, 3, 33, 28], [109, 10, 39, 16, 58, 8], [11, 64, 82, 52, 122, 27], [3, 45, 96, 66, 50, 41], [60, 8, 116, 77, 45, 82]]
# 67 50 [[77, 80, 31, 98, 26, 36], [102, 7, 22, 10, 51, 110], [4, 108, 103, 19, 110, 55], [5, 125, 63, 86, 73, 33], [99, 78, 76, 30, 91, 87]]
# ...

# %% [markdown]
# ## z=9

# %%
random_sampling(9, HOURS=HOURS)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 